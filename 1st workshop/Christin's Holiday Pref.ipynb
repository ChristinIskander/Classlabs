# %% [markdown]
# # Purpose

# %% [markdown]
# #### *the purpose of this notebook is to present christin's holiday preference*

# %%
name = input("Persons Name: ")
# Out:
# Persons Name: Christin

# %% [markdown]
# # Picture

# %% [markdown]
# ![20190805_154620.png](attachment:20190805_154620.png)

# %% [markdown]
# # Holiday Preference

# %% [markdown]
# #### *Tipp! it is a country in North Africa*

# %%
preference_country = input("in which country does Christin like to spend the holiday? ")
if preference_country == "Egypt":
    print("You got it right :)")
else:
    print("Try again")
# Out:
# in which country does Christin like to spend the holiday? Egypt
# You got it right :)

# %% [markdown]
# #### *Tipp visiting and seeing historical places*

# %%
preference_activity = input("What kind of activity does Christin like to do in Egypt? ")
if preference_activity == "sightseeing":
    print("You nailed it")
else:
    print("Try again")
# Out:
# What kind of activity does Christin like to do in Egypt? museums
# Try again

# %% [markdown]
# # This is Egypt

# %% [markdown]
# ![pyramids_holidays.jpeg](attachment:pyramids_holidays.jpeg)

# %% [markdown]
# # Top 3 things Christin does while being Egypt

# %% [markdown]
# - visit the Pyramids
# - enjoy the sun at the Beach
# - meeting up with old friends

# %% [markdown]
# <font color='red'> This is a youtube video to Christin's favorite destination </font>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('k3KqP69xuPc', width=800, height=480)
